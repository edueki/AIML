# %%
import pandas as pd

# %%
data = pd.read_csv("house_data.csv")

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sqft        1000 non-null   int64
#  1   bedrooms    1000 non-null   int64
#  2   bathrooms   1000 non-null   int64
#  3   age         1000 non-null   int64
#  4   floors      1000 non-null   int64
#  5   garage      1000 non-null   int64
#  6   lot_size    1000 non-null   int64
#  7   city_index  1000 non-null   int64
#  8   price       1000 non-null   int64
# dtypes: int64(9)
# memory usage: 70.4 KB

# %%
data.head(2)
# Out:
#    sqft  bedrooms  bathrooms  age  floors  garage  lot_size  city_index  \
# 0  1360         2          4   18       1       0      5566           1
# 1  4272         3          4   29       2       2      2909           0
#
#     price
# 0  248990
# 1  941769

# %%
data.describe()
# Out:
#               sqft     bedrooms    bathrooms          age       floors  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean   2815.422000     2.990000     2.544000    25.222000     1.467000
# std    1255.514921     1.427564     1.133732    14.313266     0.499159
# min     503.000000     1.000000     1.000000     0.000000     1.000000
# 25%    1749.500000     2.000000     2.000000    12.750000     1.000000
# 50%    2862.500000     3.000000     3.000000    26.000000     1.000000
# 75%    3849.500000     4.000000     4.000000    37.250000     2.000000
# max    4999.000000     5.000000     4.000000    49.000000     2.000000
#
#             garage     lot_size   city_index         price
# count  1000.000000  1000.000000  1000.000000  1.000000e+03
# mean      1.037000  5442.083000     4.596000  4.547957e+05
# std       0.815043  2590.933543     2.887407  2.132817e+05
# min       0.000000  1001.000000     0.000000  2.413500e+04
# 25%       0.000000  3172.750000     2.000000  2.862652e+05
# 50%       1.000000  5477.500000     5.000000  4.463070e+05
# 75%       2.000000  7678.750000     7.000000  6.124565e+05
# max       2.000000  9997.000000     9.000000  1.081841e+06

# %%
data.shape
# Out:
# (1000, 9)

# %%
data.isnull().sum()
# Out:
# sqft          0
# bedrooms      0
# bathrooms     0
# age           0
# floors        0
# garage        0
# lot_size      0
# city_index    0
# price         0
# dtype: int64

# %%
data.nunique()
# Out:
# sqft           894
# bedrooms         5
# bathrooms        4
# age             50
# floors           2
# garage           3
# lot_size       944
# city_index      10
# price         1000
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
# !python3 -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl (2.9 MB)
# Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl (65 kB)
# Downloading pillow-12.1.1-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 5.0 MB/s  0:00:01 eta 0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(9, 3))
plt.scatter(data['sqft'], data['price'])
plt.xlabel("sqft")
plt.ylabel("price")
plt.title("House price vs. sqft")
plt.show()

# %%
X = data.drop(columns=['price'])

# %%
X.head(2)
# Out:
#    sqft  bedrooms  bathrooms  age  floors  garage  lot_size  city_index
# 0  1360         2          4   18       1       0      5566           1
# 1  4272         3          4   29       2       2      2909           0

# %%
Y=data['price']

# %%
Y.head(2)
# Out:
# 0    248990
# 1    941769
# Name: price, dtype: int64

# %%
# !python3 -m pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (2.4.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl (8.1 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.0-cp311-cp311-macosx_14_0_arm64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 9.9 MB/s  0:00:02m0:00:0100:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.0 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=1)

# %%
x_train.shape
# Out:
# (900, 8)

# %%
x_test.shape
# Out:
# (100, 8)

# %%
y_train.shape
# Out:
# (900,)

# %%
y_test.shape
# Out:
# (100,)

# %%
x_train.head(2)
# Out:
#      sqft  bedrooms  bathrooms  age  floors  garage  lot_size  city_index
# 335  2431         3          2   29       1       1      8933           8
# 13   1684         5          2   47       1       0      4121           9

# %%
y_train.head(2)
# Out:
# 335    502829
# 13     212143
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test.head(2)
# Out:
#      sqft  bedrooms  bathrooms  age  floors  garage  lot_size  city_index
# 507  2031         3          3   49       1       2      2882           6
# 818  1754         2          3    7       1       1      8942           4

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([348197.74911404, 299019.28083449, 251921.32701914, 640225.22548165,
#        606257.32727309, 210610.33232938, 192858.88598546, 704383.30637266,
#        109453.37927219, 584189.04639761, 135446.58028038, 607176.82594717,
#        678289.90587371, 354918.68789022, 214519.05015669, 225445.72268748,
#        181688.03135881, 573166.59691546, 603816.42145352, 658159.53514215,
#        442178.29035933, 484237.12780303, 378347.89546755, 549298.01873103,
#        212977.22174838, 325694.15836557, 565989.13107833, 196338.17287625,
#        418717.85581874, 569302.24262136, 702942.71885816, 281961.61457805,
#        369004.21289844, 716722.14378076, 154551.40869735, 216646.71597592,
#        499456.71001221, 296304.68350289, 717068.49819106, 562119.31581477,
#        594904.58409292, 292202.97203262, 508113.20592855, 367033.88390041,
#        699863.90346325, 608517.99531059, 794322.15534058, 519433.74940734,
#        498287.56954021, 532731.12131244, 607156.87014565, 538135.66408808,
#        607482.36218463, 493938.43565108, 231289.78214429, 451043.15039289,
#        557401.666593  , 394807.27711109, 373229.44508029, 619967.89366386,
#        674367.41001524, 360909.0411674 , 517276.94414216, 270171.76633228,
#        530464.15190485, 414222.50271561, 606433.28730196, 394029.65062115,
#        632497.15943206, 160308.79764602, 483100.76512459, 355658.39860003,
#        483729.54502669, 399533.57427343, 577482.54165261, 323668.91628061,
#        582187.84300253, 681290.35694163, 183907.79554197, 392038.46607928,
#        255907.11819965, 790396.13619912, 684555.64805301, 330244.54536102,
#        138535.6757546 , 644438.14400325, 588882.63235719, 214208.66309862,
#        412400.52275556, 630871.58727841, 427742.70033412, 368088.49636297,
#        620556.54417915, 771114.77775758, 615905.8372999 , 179012.33213106,
#        235153.02140814, 427032.3439521 , 173246.61607395, 520831.74560954])

# %%
y_test
# Out:
# 507    372878
# 818    263728
# 452    245578
# 368    934349
# 242    684022
#         ...
# 671    183110
# 559    188679
# 593    313166
# 258    168136
# 154    640142
# Name: price, Length: 100, dtype: int64

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.7680771717914677

# %%
# !python3 -m pip install joblib
# Out:
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (1.5.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
import joblib

# %%
joblib.dump(model, "housemodel.pkl")
# Out:
# ['housemodel.pkl']
